# %%
import pandas as pd

# %%
df = pd.read_csv("movie_dataset.csv")

# %%
df.columns
# Out:
# Index(['id', 'title', 'genre', 'original_language', 'overview', 'popularity',
#        'release_date', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                  genre original_language  \
# 0                                          Drama,Crime                en
# ...

# %%
df.isnull().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %%
import tkinter as tk
root = tk.Tk()
root.geometry("500x400")
root.title("movie recommandation system")

header = tk.Label(root, text = "movie recommadation system")
font=("Arial"18,"bold"))

header.pack(pady=15)

tk.Label(root,text="selection"

tk.Button(root,text="show Recommand")
font=("Areial",14,"bold")).pack(pady=10)

result_list = tk.

root.mainloop()
# Out:
#   Cell In[14], line 7
#     font=("Arial"18,"bold"))
#                            ^
# SyntaxError: unmatched ')'
